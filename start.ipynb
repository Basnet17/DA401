# %%
import os
os.getcwd()
# Out:
# '/Users/pritam/Desktop/DA401'

# %%
import sys
sys.path.append('/Library/Developer/CommandLineTools/usr/bin/python3')

import praw
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-5dc4f848e6e3> in <module>
#       2 sys.path.append('/Library/Developer/CommandLineTools/usr/bin/python3')
#       3
# ----> 4 import praw
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'praw'

# %%
import praw
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-ff8474903dfd> in <module>
# ----> 1 import praw
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'praw'
